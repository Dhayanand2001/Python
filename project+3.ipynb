# %%
import pandas as pd
import numpy as np
data=pd.read_csv('youtube_dislike_dataset.csv')
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
data.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
data.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
#2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         37422 non-null  object
#  1   title            37422 non-null  object
#  2   channel_id       37422 non-null  object
#  3   channel_title    37422 non-null  object
#  4   published_at     37422 non-null  object
#  5   view_count       37422 non-null  int64
#  6   likes            37422 non-null  int64
#  7   dislikes         37422 non-null  int64
#  8   comment_count    37422 non-null  int64
#  9   tags             37422 non-null  object
#  10  description      37422 non-null  object
#  11  comments         37264 non-null  object
#  12  published        37422 non-null  datetime64[ns]
#  13  published_month  37422 non-null  int32
# dtypes: datetime64[ns](1), int32(1), int64(4), object(8)
# memory usage: 3.9+ MB

# %%
#3. Check for the Percentage of the missing values and drop or impute them.
data.isnull().sum()*100/len(data)
# Out:
# video_id           0.000000
# title              0.000000
# channel_id         0.000000
# channel_title      0.000000
# published_at       0.000000
# view_count         0.000000
# likes              0.000000
# dislikes           0.000000
# comment_count      0.000000
# tags               0.000000
# description        0.000000
# comments           0.422212
# published          0.000000
# published_month    0.000000
# dtype: float64

# %%
we can observe that comments column have 0.42% of null values.

# %%
#4. Check the statistical summary of both numerical and categorical columns and write your inferences
data.describe()
# Out:
#          view_count         likes      dislikes  comment_count  \
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
#
#                            published  published_month
# count                          37422     37422.000000
# mean   2021-04-10 13:04:18.237827840         7.495377
# min              2020-07-27 21:49:32         1.000000
# 25%    2020-12-01 12:00:13.750000128         5.000000
# 50%              2021-04-10 11:00:11         8.000000
# 75%    2021-08-15 23:00:08.249999872        10.000000
# ...

# %%
### Inference:
- We can observe that the maximum view count is around 1 Billion.
- The average likes are around 1.5 lakhs and dislikes average is around 5K.
- *Sky Sports Football* channel has the top frequency having 533 instances in the dataset.

# %%
#5.
import pandas as pd
data=pd.read_csv('youtube_dislike_dataset.csv')
df_datetime=pd.to_datetime(data['published_at'])
print(df_datetime.dtype)
# Out:
# datetime64[ns]

# %%
#6.
data['published']=pd.to_datetime(data['published_at'])
data['published_month']=data['published'].dt.month
data[['published','published_month']].head()
# Out:
#             published  published_month
# 0 2021-07-01 10:00:00                7
# 1 2021-06-10 16:00:00                6
# 2 2021-09-20 01:03:32                9
# 3 2021-03-03 10:00:17                3
# 4 2021-12-07 13:00:00               12

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
#7.
month={1:'January',
    2:'February',
    3:'March',
    4:'April',
    5:'May',
    6:'June',
    7:'July',
    8:'August',
    9:'September',
    10:'October',
    11:'November',
    12:'December'}
data['published_month'].map(month)
# Out:
# 0             July
# 1             June
# 2        September
# 3            March
# 4         December
#            ...
# 37417     February
# 37418      January
# 37419         June
# 37420      October
# 37421          May
# Name: published_month, Length: 37422, dtype: object

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
#8.
import pandas as pd
data = pd.read_csv('youtube_dislike_dataset.csv')
data['published_at']=pd.to_datetime(data['published_at'])
data['published_month']=data['published_at'].dt.month
data['published_month']=data['published_month'].map(month)
COUNTS=data['published_month'].value_counts()
SCOUNTS=COUNTS.sort_values(ascending=False)
SCOUNTS
# Out:
# published_month
# October      4991
# September    4880
# November     4851
# August       4262
# December     3072
# July         2340
# June         2316
# March        2258
# February     2137
# April        2126
# January      2108
# May          2081
# Name: count, dtype: int64

# %%
#9. Find the count of unique video_id, channel_id and channel_title.

# %%
data['video_id'].count()
# Out:
# 37422

# %%
data['channel_id'].count()
# Out:
# 37422

# %%
data['channel_title'].count()
# Out:
# 37422

# %%
#10.Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.
data.groupby('channel_title')['video_id'].count().sort_values(ascending=False).head(10)
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64

# %%
#11.data.groupby('channel_title')['video_id'].count().sort_values(ascending=False).head(10)
pd.pivot_table(data, index = ['title'], values = ['likes'], aggfunc = np.max).sort_values(by = 'likes', ascending = False).head(10)
# Out:
#                                                        likes
# title
# BTS () 'Dynamite' Official MV                       31837675
# BTS () 'Butter' Official MV                         20649409
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V     17864527
# BTS () 'Life Goes On' Official MV                   16354127
# BTS () 'Permission to Dance' Official MV            15449003
# LISA - 'LALISA' M/V                                 14680271
# BLACKPINK - 'Lovesick Girls' M/V                    13641573
# THIS NEARLY GAVE HIM A HEART ATTACK!                12219447
# $456,000 Squid Game In Real Life!                   11729606
# Bella Poarch - Build a B*tch (Official Music Vi...  10734829

# %%
#12.Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.
pd.pivot_table(data,index=['title'],values=['dislikes'],aggfunc=np.max).sort_values(by ='dislikes', ascending = False).head(10)
# Out:
#                                                     dislikes
# title
# Cuties | Official Trailer | Netflix                  2397733
# BTS () 'Dynamite' Official MV                        1814333
# Cardi B - WAP feat. Megan Thee Stallion [Offici...   1331181
# 52 GAJ KA DAMAN | PRANJAL DAHIYA | AMAN JAJI | ...   1259533
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V      1253187
# Lil Nas X - MONTERO (Call Me By Your Name) (Off...   1224559
# Tip Chocolate Hacks With Balloon                      802354
# Coke & Mentos Bottle INSIDE Balloon!! *Experime...    724993
# A STORY ABOUT GREED                                   643536
# THIS NEARLY GAVE HIM A HEART ATTACK!                  620645

# %% [markdown]
# Inference: 'Cuties | Offical Trailer | Netflix' has the highest number of dislikes.

# %%
#Q13) Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data[['view_count','dislikes']].corr(),annot= True ,cmap='crest')
plt.show()

# %%
#Q14) Display all the information about the videos that were published in January, and mention the count of videos that were published in January.
data['published_at'] = pd.to_datetime(data['published_at'])
data['published_month']=data['published_at'].dt.month
data['published_month']=data['published_month'].map(month)
JAnYuArY=data[data['published_month'] == 'January']
print("Videos published in January")
JAnYuArY
# Out:
# Videos published in January
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
Count_Videos=len(JAnYuArY)
print("Count of videos published in January:",Count_Videos)
# Out:
# Count of videos published in January: 2108
